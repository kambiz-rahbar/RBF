# %%
from numpy import arange
from scipy.stats import norm
from matplotlib.pyplot import plot

# %%
x = arange(-3,3,0.1)
y = norm(0,.5)

a1 = y.pdf(x)
a2 = y.pdf((x-1.5))
a3 = 0.5*(y.pdf((x+2)))
a4 = a1+a2+a3

plot(x,a1,'-y',x,a2,'-g',x,a3,'-r',x,a4,'-b');
